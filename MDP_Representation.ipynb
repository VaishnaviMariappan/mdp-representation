# %%
P = {
    0 : {
        0 : [(0.12, 0, 0.0, False)],
        1 : [(0.87, 2, 0.0, False)],
        2 : [(0.23, 0, 0.0, False)],
        3 : [(0.23, 0, 0.0, False)]
    },

    1 : {
        0 : [(0.45, 2, 0.0, False)],
        1 : [(0.87, 4, 0.0, False)],
        2 : [(0.23, 1, 0.0, False)],
        3 : [(0.23, 1, 0.0, False)]
    },

    2 : {
        0 : [(0.67, 3, 0.0, False)],
        1 : [(0.98, 5, 0.0, False)],
        2 : [(0.67, 1, 0.0, False)],
        3 : [(0.34, 0, 0.0, False)]
    },

    3 : {
        0 : [(0.23, 3, 0.0, False)],
        1 : [(0.98, 6, 0.0, False)],
        2 : [(0.76, 2, 0.0, False)],
        3 : [(0.12, 3, 0.0, False)]
    },

    4 : {
        0 : [(0.76, 5, 0.0, False)],
        1 : [(0.11, 4, 0.0, False)],
        2 : [(0.11, 4, 0.0, False)],
        3 : [(0.32, 1, 0.0, False)]
    },

    5 : {
        0 : [(0.65, 6, 0.0, False)],
        1 : [(0.99, 7, 1.0, True)],
        2 : [(0.65, 4, 0.0, False)],
        3 : [(0.34, 2, 0.0, False)]
    },

    6 : {
        0 : [(0.11, 6, 0.0, False)],
        1 : [(0.11, 6, 0.0, False)],
        2 : [(0.87, 5, 0.0, False)],
        3 : [(0.66, 3, 0.0, False)]
    },

    7 : {
        0 : [(0.98, 7, 1.0, True)],
        1 : [(0.65, 7, 1.0, True)],
        2 : [(0.89, 7, 1.0, True)],
        3 : [(0.88, 7, 1.0, True)]
    },
}

# %%
P
# Out:
# {0: {0: [(0.12, 0, 0.0, False)],
#   1: [(0.87, 2, 0.0, False)],
#   2: [(0.23, 0, 0.0, False)],
#   3: [(0.23, 0, 0.0, False)]},
#  1: {0: [(0.45, 2, 0.0, False)],
#   1: [(0.87, 4, 0.0, False)],
#   2: [(0.23, 1, 0.0, False)],
#   3: [(0.23, 1, 0.0, False)]},
#  2: {0: [(0.67, 3, 0.0, False)],
#   1: [(0.98, 5, 0.0, False)],
#   2: [(0.67, 1, 0.0, False)],
#   3: [(0.34, 0, 0.0, False)]},
#  3: {0: [(0.23, 3, 0.0, False)],
#   1: [(0.98, 6, 0.0, False)],
#   2: [(0.76, 2, 0.0, False)],
#   3: [(0.12, 3, 0.0, False)]},
#  4: {0: [(0.76, 5, 0.0, False)],
#   1: [(0.11, 4, 0.0, False)],
#   2: [(0.11, 4, 0.0, False)],
#   3: [(0.32, 1, 0.0, False)]},
#  5: {0: [(0.65, 6, 0.0, False)],
#   1: [(0.99, 7, 1.0, True)],
#   2: [(0.65, 4, 0.0, False)],
#   3: [(0.34, 2, 0.0, False)]},
#  6: {0: [(0.11, 6, 0.0, False)],
#   1: [(0.11, 6, 0.0, False)],
#   2: [(0.87, 5, 0.0, False)],
#   3: [(0.66, 3, 0.0, False)]},
#  7: {0: [(0.98, 7, 1.0, True)],
#   1: [(0.65, 7, 1.0, True)],
# ...
