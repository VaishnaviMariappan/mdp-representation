# %%
P = {
    0 : {
        0 : [(1.0, 0, 0.0, False)],
        1 : [(1.0, 2, 0.0, False)],
        2 : [(1.0, 0, 0.0, False)],
        3 : [(1.0, 0, 0.0, False)]
    },

    1 : {
        0 : [(0.85, 2, 0.0, False), (0.15, 1, 0.0, False)],
        1 : [(0.85, 4, 0.0, False), (0.15, 1, 0.0, False)],
        2 : [(1.0, 1, 0.0, False)],
        3 : [(1.0, 1, 0.0, False)]
    },

    2 : {
        0 : [(0.85, 3, 0.0, False), (0.15, 2, 0.0, False)],
        1 : [(0.85, 5, 0.0, False), (0.15, 2, 0.0, False)],
        2 : [(0.85, 1, 0.0, False), (0.15, 2, 0.0, False)],
        3 : [(0.85, 0, 0.0, False), (0.15, 2, 0.0, False)]
    },

    3 : {
        0 : [(1.0, 3, 0.0, False)],
        1 : [(0.85, 6, 0.0, False), (0.15, 3, 0.0, False)],
        2 : [(0.85, 2, 0.0, False), (0.15, 3, 0.0, False)],
        3 : [(1.0, 3, 0.0, False)]
    },

    4 : {
        0 : [(0.85, 5, 0.0, False), (0.15, 4, 0.0, False)],
        1 : [(1.0, 4, 0.0, False)],
        2 : [(1.0, 4, 0.0, False)],
        3 : [(0.85, 1, 0.0, False), (0.15, 4, 0.0, False)]
    },

    5 : {
        0 : [(0.85, 6, 0.0, False), (0.15, 5, 0.0, False)],
        1 : [(0.85, 7, 1.0, True), (0.15, 5, 0.0, False)],
        2 : [(0.85, 4, 0.0, False), (0.15, 5, 0.0, False)],
        3 : [(0.34, 2, 0.0, False), (0.15, 5, 0.0, False)]
    },

    6 : {
        0 : [(1.0, 6, 0.0, False)],
        1 : [(1.0, 6, 0.0, False)],
        2 : [(0.85, 5, 0.0, False), (0.15, 6, 0.0, False)],
        3 : [(0.85, 3, 0.0, False), (0.15, 6, 0.0, False)]
    },

    7 : {
        0 : [(1.0, 7, 0.0, True)],
        1 : [(1.0, 7, 0.0, True)],
        2 : [(1.0, 7, 0.0, True)],
        3 : [(1.0, 7, 0.0, True)]
    },
}

# %%
P
# Out:
# {0: {0: [(1.0, 0, 0.0, False)],
#   1: [(1.0, 2, 0.0, False)],
#   2: [(1.0, 0, 0.0, False)],
#   3: [(1.0, 0, 0.0, False)]},
#  1: {0: [(0.85, 2, 0.0, False), (0.15, 1, 0.0, False)],
#   1: [(0.85, 4, 0.0, False), (0.15, 1, 0.0, False)],
#   2: [(1.0, 1, 0.0, False)],
#   3: [(1.0, 1, 0.0, False)]},
#  2: {0: [(0.85, 3, 0.0, False), (0.15, 2, 0.0, False)],
#   1: [(0.85, 5, 0.0, False), (0.15, 2, 0.0, False)],
#   2: [(0.85, 1, 0.0, False), (0.15, 2, 0.0, False)],
#   3: [(0.85, 0, 0.0, False), (0.15, 2, 0.0, False)]},
#  3: {0: [(1.0, 3, 0.0, False)],
#   1: [(0.85, 6, 0.0, False), (0.15, 3, 0.0, False)],
#   2: [(0.85, 2, 0.0, False), (0.15, 3, 0.0, False)],
#   3: [(1.0, 3, 0.0, False)]},
#  4: {0: [(0.85, 5, 0.0, False), (0.15, 4, 0.0, False)],
#   1: [(1.0, 4, 0.0, False)],
#   2: [(1.0, 4, 0.0, False)],
#   3: [(0.85, 1, 0.0, False), (0.15, 4, 0.0, False)]},
#  5: {0: [(0.85, 6, 0.0, False), (0.15, 5, 0.0, False)],
#   1: [(0.85, 7, 1.0, True), (0.15, 5, 0.0, False)],
#   2: [(0.85, 4, 0.0, False), (0.15, 5, 0.0, False)],
#   3: [(0.34, 2, 0.0, False), (0.15, 5, 0.0, False)]},
#  6: {0: [(1.0, 6, 0.0, False)],
#   1: [(1.0, 6, 0.0, False)],
#   2: [(0.85, 5, 0.0, False), (0.15, 6, 0.0, False)],
#   3: [(0.85, 3, 0.0, False), (0.15, 6, 0.0, False)]},
#  7: {0: [(1.0, 7, 0.0, True)],
#   1: [(1.0, 7, 0.0, True)],
#   2: [(1.0, 7, 0.0, True)],
#   3: [(1.0, 7, 0.0, True)]}}
