# %%
P = {
    0 : {
        0 : [(1.0, 0, 0.0, False)],
        1 : [(1.0, 2, 0.0, False)],
        2 : [(1.0, 0, 0.0, False)],
        3 : [(1.0, 0, 0.0, False)]
    },

    1 : {
        0 : [(1.0, 2, 0.0, False)],
        1 : [(1.0, 4, 0.0, False)],
        2 : [(1.0, 1, 0.0, False)],
        3 : [(1.0, 1, 0.0, False)]
    },

    2 : {
        0 : [(1.0, 3, 0.0, False)],
        1 : [(1.0, 5, 0.0, False)],
        2 : [(1.0, 1, 0.0, False)],
        3 : [(1.0, 0, 0.0, False)]
    },

    3 : {
        0 : [(1.0, 3, 0.0, False)],
        1 : [(1.0, 6, 0.0, False)],
        2 : [(1.0, 2, 0.0, False)],
        3 : [(1.0, 3, 0.0, False)]
    },

    4 : {
        0 : [(1.0, 5, 0.0, False)],
        1 : [(1.0, 4, 0.0, False)],
        2 : [(1.0, 4, 0.0, False)],
        3 : [(1.0, 1, 0.0, False)]
    },

    5 : {
        0 : [(1.0, 6, 0.0, False)],
        1 : [(1.0, 7, 1.0, True)],
        2 : [(1.0, 4, 0.0, False)],
        3 : [(1.0, 2, 0.0, False)]
    },

    6 : {
        0 : [(1.0, 6, 0.0, False)],
        1 : [(1.0, 6, 0.0, False)],
        2 : [(1.0, 5, 0.0, False)],
        3 : [(1.0, 3, 0.0, False)]
    },

    7 : {
        0 : [(1.0, 7, 1.0, True)],
        1 : [(1.0, 7, 1.0, True)],
        2 : [(1.0, 7, 1.0, True)],
        3 : [(1.0, 7, 1.0, True)]
    },
}

# %%
P
# Out:
# {0: {0: [(1.0, 0, 0.0, False)],
#   1: [(1.0, 2, 0.0, False)],
#   2: [(1.0, 0, 0.0, False)],
#   3: [(1.0, 0, 0.0, False)]},
#  1: {0: [(1.0, 2, 0.0, False)],
#   1: [(1.0, 4, 0.0, False)],
#   2: [(1.0, 1, 0.0, False)],
#   3: [(1.0, 1, 0.0, False)]},
#  2: {0: [(1.0, 3, 0.0, False)],
#   1: [(1.0, 5, 0.0, False)],
#   2: [(1.0, 1, 0.0, False)],
#   3: [(1.0, 0, 0.0, False)]},
#  3: {0: [(1.0, 3, 0.0, False)],
#   1: [(1.0, 6, 0.0, False)],
#   2: [(1.0, 2, 0.0, False)],
#   3: [(1.0, 3, 0.0, False)]},
#  4: {0: [(1.0, 5, 0.0, False)],
#   1: [(1.0, 4, 0.0, False)],
#   2: [(1.0, 4, 0.0, False)],
#   3: [(1.0, 1, 0.0, False)]},
#  5: {0: [(1.0, 6, 0.0, False)],
#   1: [(1.0, 7, 1.0, True)],
#   2: [(1.0, 4, 0.0, False)],
#   3: [(1.0, 2, 0.0, False)]},
#  6: {0: [(1.0, 6, 0.0, False)],
#   1: [(1.0, 6, 0.0, False)],
#   2: [(1.0, 5, 0.0, False)],
#   3: [(1.0, 3, 0.0, False)]},
#  7: {0: [(1.0, 7, 1.0, True)],
#   1: [(1.0, 7, 1.0, True)],
#   2: [(1.0, 7, 1.0, True)],
# ...
